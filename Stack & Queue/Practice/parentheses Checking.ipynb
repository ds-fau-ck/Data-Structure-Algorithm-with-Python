# %%
def valid_parentheses(exp):
    stack=[]
    for char in exp:
        if char in ["(","{","["]:
            stack.append(char)
    
        elif char in [")","}","]"]:
            alpha=stack.pop()
            
        
            if alpha== "(":
                if char !=")":
                    return False
            if alpha=="{":
                if char !="}":
                    return False
            if alpha=="[":
                if char
    return stack
exp="(()[]{})"
stk=valid_parentheses(exp)
print(stk)
# Out:
# (
# [
# {
# (
# []
