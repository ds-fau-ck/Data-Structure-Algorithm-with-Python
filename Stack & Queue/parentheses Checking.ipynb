# %%
def BracketBalanceChecking(exp):
    stack=[]
    for char in exp:
        if char in ["(","[","{"]:
            stack.append(char)
        elif char in [")","]","}"]:
            alpha=stack.pop()
            if alpha=="(":
                if char!=")":
                    return False
            if alpha=="[":
                if char !="]":
                    return False
            if alpha=="{":
                if char !="}":
                    return False
    if stack:
        return False
    return True
            
            
exp="{()[]}"
flag=BracketBalanceChecking(exp)
print(flag)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9016\2300723693.py in <module>
#      21
#      22 exp="{()[]}"
# ---> 23 flag=BracketBalanceChecking(exp)
#      24 print(flag)
#
# ~\AppData\Local\Temp\ipykernel_9016\2300723693.py in BracketBalanceChecking(exp)
#       2     stack=[]
#       3     for char in exp:
# ----> 4         if char in stack["(","[","{"]:
#       5             stack.append(char)
#       6         elif char in [")","]","}"]:
#
# TypeError: list indices must be integers or slices, not tuple
